# %% [markdown]
# <a href="https://colab.research.google.com/github/Kashika18/Machine-Learing-Basics/blob/main/Activity3_ACM_KashikaJain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # NUMERIC DATA:

# %%
df=pd.read_csv('popularity - popularity.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  avg_shares  avg_comments  avg_expert  popularity_score
# 0          19       147.3          23.9        19.1              14.6
# 1          91        28.6           1.5        33.0               7.3
# 2         166        17.9          37.6        21.6               8.0
# 3         196        94.2           4.9         8.1               9.7
# 4          42       293.6          27.7         1.8              20.7

# %% [markdown]
# 1.1 Remove the first column of ‘Unnamed: 0’

# %%
df.drop(['Unnamed: 0'], axis='columns',inplace=True)
df
# Out:
#      avg_shares  avg_comments  avg_expert  popularity_score
# 0         147.3          23.9        19.1              14.6
# 1          28.6           1.5        33.0               7.3
# 2          17.9          37.6        21.6               8.0
# 3          94.2           4.9         8.1               9.7
# 4         293.6          27.7         1.8              20.7
# ..          ...           ...         ...               ...
# 195         4.1          11.6         5.7               3.2
# 196        76.4          26.7        22.3              11.8
# 197       218.5           5.4        27.4              12.2
# 198       140.3           1.9         9.0              10.3
# 199       266.9          43.8         5.0              25.4
#
# [200 rows x 4 columns]

# %% [markdown]
# 1.2 Detect missing values, and replace them with the mean.

# %%
df.isnull().sum()
# Out:
# avg_shares          1
# avg_comments        4
# avg_expert          0
# popularity_score    0
# dtype: int64

# %%
df.mean()
# Out:
# avg_shares          147.291457
# avg_comments         23.319388
# avg_expert           30.554000
# popularity_score     14.022500
# dtype: float64

# %%
df.fillna(df.mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# avg_shares          0
# avg_comments        0
# avg_expert          0
# popularity_score    0
# dtype: int64

# %% [markdown]
# 1.3 Draw box-plots for each attribute to detect if there are any outliers.

# %%
import seaborn as sns

# %%
sns.boxplot( data=df)

# %% [markdown]
# we can see outliners for avg_expert

# %% [markdown]
# 1.4 Normalize all attributes within the range of 0 to 1.

# %%
from sklearn import preprocessing

# %%
# normalize the data attributes
normalized=preprocessing.normalize(df)

# %%
normalized
# Out:
# array([[0.97452547, 0.15812056, 0.12636413, 0.09659248],
#        [0.64559655, 0.03385996, 0.7449191 , 0.16478513],
#        [0.37613592, 0.79009557, 0.45388469, 0.16810544],
#        [0.98980656, 0.05148675, 0.08511076, 0.10192276],
#        [0.99311693, 0.09369666, 0.00608859, 0.0700188 ],
#        [0.87182477, 0.29334786, 0.37300697, 0.12138532],
#        [0.99295394, 0.01292132, 0.10535848, 0.05267924],
#        [0.98543442, 0.13645919, 0.07490238, 0.06846546],
#        [0.99507553, 0.03586818, 0.07599792, 0.05255931],
#        [0.56638775, 0.46712392, 0.65105396, 0.19268862],
#        [0.98116689, 0.12789885, 0.09957839, 0.10505977],
#        [0.99538328, 0.0522998 , 0.03599126, 0.07198252],
#        [0.9376841 , 0.11483783, 0.31920488, 0.07529312],
#        [0.98922489, 0.11459008, 0.04583603, 0.07875464],
#        [0.99695836, 0.03694029, 0.03736983, 0.05755813],
#        [0.98926685, 0.04016356, 0.12622835, 0.06167976],
# ...

# %% [markdown]
# # CATEGORICAL DATA:

# %%
data = pd.read_excel('test.xlsx')

# %%
data.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %% [markdown]
# 2.1 Detect missing values in the age column, and replace them with the mean.

# %%
data['Age'].isnull().sum()
# Out:
# 86

# %% [markdown]
# There are 86 missing values in the age column

# %%
data.mean()
# Out:
# PassengerId    1100.500000
# Pclass            2.265550
# Age              30.272590
# SibSp             0.447368
# Parch             0.392344
# Fare             35.627188
# dtype: float64

# %%
data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# All null values of the age column have been replaced by the mean.

# %% [markdown]
# 2.2 Encode each variable in columns-sex and embarked to integers.

# %%
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
data["Sex"] = ord_enc.fit_transform(data[["Sex"]])

data["Embarked"] = ord_enc.fit_transform(data[["Embarked"]])
data.head()
# Out:
#    PassengerId  Pclass  ... Cabin  Embarked
# 0          892       3  ...   NaN       1.0
# 1          893       3  ...   NaN       2.0
# 2          894       2  ...   NaN       1.0
# 3          895       3  ...   NaN       2.0
# 4          896       3  ...   NaN       2.0
#
# [5 rows x 11 columns]

# %% [markdown]
# Drop the columns which are not required

# %%
data['Cabin'].isnull().sum()
# Out:
# 327

# %% [markdown]
# dropping 'Cabin' as it mostly has null values

# %%
data.drop('Cabin',axis='columns',inplace=True)

# %%
data.head(5)
# Out:
#    PassengerId  Pclass  ...     Fare  Embarked
# 0          892       3  ...   7.8292       1.0
# 1          893       3  ...   7.0000       2.0
# 2          894       2  ...   9.6875       1.0
# 3          895       3  ...   8.6625       2.0
# 4          896       3  ...  12.2875       2.0
#
# [5 rows x 10 columns]

# %% [markdown]
# # IMAGE DATA

# %% [markdown]
# 3.1 Convert image to Black and white.

# %%
#example of saving a grayscale version of a loaded image
from PIL import Image
# load the image
image = Image.open('opera_house.jpg')
# convert the image to grayscale
gs_image = image.convert(mode='L')
# save in jpeg format
gs_image.save('opera_house_grayscale.jpg')
# load the image again and show it
image2 = Image.open('opera_house_grayscale.jpg')

#displaying image
from IPython.display import display
display(image2)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1884x779 at 0x7FD093DECED0>

# %% [markdown]
# 3.2 Resize image to 100*100.

# %%
# report the size of the image
print(image.size)
# create a thumbnail and preserve aspect ratio
image.thumbnail((100,100))
# report the size of the thumbnail
print(image.size)
# Out:
# (1884, 779)
# (100, 41)

# %%
#report the size of the image
print(image.size)
# resize image and ignore original aspect ratio
img_resized = image.resize((100,100))
# report the size of the thumbnail
print(img_resized.size)

display(img_resized)
# Out:
# (100, 41)
# (100, 100)
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FD0916628D0>

# %% [markdown]
# 3.3 Convert given image into a numpy array.

# %%
from numpy import asarray

# convert image to numpy array
data = asarray(image)

# summarize shape
print(data.shape)

# create Pillow image
image2 = Image.fromarray(data)

# summarize image details
print(image2.format)
print(image2.mode)
print(image2.size)

#printing the array
data
# Out:
# (41, 100, 3)
# None
# RGB
# (100, 41)
# array([[[  2,  40,  88],
#         [  1,  40,  89],
#         [  0,  40,  89],
#         ...,
#         [  1,  89, 143],
#         [  1,  79, 136],
#         [  1,  68, 124]],
#
#        [[  2,  40,  85],
#         [  1,  41,  87],
#         [  1,  41,  87],
#         ...,
#         [  1,  83, 138],
#         [  1,  73, 128],
#         [  0,  65, 119]],
#
#        [[  1,  39,  84],
#         [  1,  40,  85],
#         [  0,  41,  85],
#         ...,
#         [  1,  65, 120],
#         [  1,  62, 115],
#         [  1,  58, 112]],
#
#        ...,
#
#        [[104,  45,  69],
#         [109,  46,  70],
#         [115,  47,  66],
#         ...,
#         [  2,  79, 126],
#         [  2,  79, 128],
#         [  2,  80, 126]],
#
#        [[ 97,  41,  64],
#         [102,  41,  62],
#         [103,  39,  59],
#         ...,
#         [  3,  74, 123],
#         [  1,  76, 123],
#         [  1,  77, 123]],
#
#        [[ 85,  33,  55],
# ...

# %% [markdown]
# #TEXT DATA

# %%
import nltk
nltk.download('stopwords')

file = pd.read_csv('a3-Q4 - a3-Q4.csv')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
file
# Out:
#          tweet_id  ...                                            content
# 0      1956967341  ...  @tiffanylue i know  i was listenin to bad habi...
# 1      1956967666  ...  Layin n bed with a headache  ughhhh...waitin o...
# 2      1956967696  ...                Funeral ceremony...gloomy friday...
# 3      1956967789  ...               wants to hang out with friends SOON!
# 4      1956968416  ...  @dannycastillo We want to trade with someone w...
# ...           ...  ...                                                ...
# 39995  1753918954  ...                                   @JohnLloydTaylor
# 39996  1753919001  ...                     Happy Mothers Day  All my love
# 39997  1753919005  ...  Happy Mother's Day to all the mommies out ther...
# 39998  1753919043  ...  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  1753919049  ...  @mopedronin bullet train from tokyo    the gf ...
#
# [40000 rows x 4 columns]

# %% [markdown]
#  4.1 Filter out Punctuation

# %%
#load data
filename = 'a3-Q4 - a3-Q4.csv'
file = open(filename, 'rt')
text = file.read()
file.close()
# remove all tokens that are not alphabetic
words = [word for word in tokens if word.isalpha()]
print(words[:100])
# Out:
# ['sentiment', 'author', 'content', 'empty', 'xoshayzers', 'tiffanylue', 'i', 'know', 'i', 'was', 'listenin', 'to', 'bad', 'habit', 'earlier', 'and', 'i', 'started', 'freakin', 'at', 'his', 'part', 'sadness', 'wannamama', 'Layin', 'n', 'bed', 'with', 'a', 'headache', 'ughhhh', 'waitin', 'on', 'your', 'call', 'sadness', 'coolfunky', 'Funeral', 'ceremony', 'gloomy', 'friday', 'enthusiasm', 'czareaquino', 'wants', 'to', 'hang', 'out', 'with', 'friends', 'SOON', 'neutral', 'xkilljoyx', 'dannycastillo', 'We', 'want', 'to', 'trade', 'with', 'someone', 'who', 'has', 'Houston', 'tickets', 'but', 'no', 'one', 'will', 'worry', 'xxxPEACHESxxx', 'why', 'did', 'you', 'go', 'to', 'prom', 'BC', 'my', 'bf', 'did', 'like', 'my', 'friends', 'sadness', 'ShansBee', 'I', 'should', 'be', 'sleep', 'but', 'im', 'not', 'thinking', 'about', 'an', 'old', 'friend', 'who', 'I', 'want', 'but']

# %% [markdown]
# 4.2 Filter out stop words

# %%
# convert to lower case
tokens = [w.lower() for w in tokens]
# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]
# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]
# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print(words[:100])
# Out:
# ['tweetid', 'sentiment', 'author', 'content', 'empty', 'xoshayzers', 'tiffanylue', 'know', 'listenin', 'bad', 'habit', 'earlier', 'started', 'freakin', 'part', 'sadness', 'wannamama', 'layin', 'n', 'bed', 'headache', 'ughhhh', 'waitin', 'call', 'sadness', 'coolfunky', 'funeral', 'ceremony', 'gloomy', 'friday', 'enthusiasm', 'czareaquino', 'wants', 'hang', 'friends', 'soon', 'neutral', 'xkilljoyx', 'dannycastillo', 'want', 'trade', 'someone', 'houston', 'tickets', 'one', 'worry', 'xxxpeachesxxx', 'repinging', 'nt', 'go', 'prom', 'bc', 'bf', 'nt', 'like', 'friends', 'sadness', 'shansbee', 'sleep', 'im', 'thinking', 'old', 'friend', 'want', 'married', 'damn', 'amp', 'wants', 'scandalous', 'worry', 'mcsleazy', 'hmmm', 'http', 'wwwdjherocom', 'sadness', 'charviray', 'charlene', 'love', 'miss', 'sadness', 'ingenueem', 'kelcouch', 'sorry', 'least', 'friday', 'neutral', 'feinyheiny', 'cant', 'fall', 'asleep', 'worry', 'dudeitsmanda', 'choked', 'retainers', 'sadness', 'ugh', 'beat', 'stupid',
# ...

# %% [markdown]
# 4.3 Split into Words

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')
tokens = word_tokenize(text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
print(tokens[:100])
# Out:
# ['tweet_id', ',', 'sentiment', ',', 'author', ',', 'content', '1956967341', ',', 'empty', ',', 'xoshayzers', ',', '@', 'tiffanylue', 'i', 'know', 'i', 'was', 'listenin', 'to', 'bad', 'habit', 'earlier', 'and', 'i', 'started', 'freakin', 'at', 'his', 'part', '=', '[', '1956967666', ',', 'sadness', ',', 'wannamama', ',', 'Layin', 'n', 'bed', 'with', 'a', 'headache', 'ughhhh', '...', 'waitin', 'on', 'your', 'call', '...', '1956967696', ',', 'sadness', ',', 'coolfunky', ',', 'Funeral', 'ceremony', '...', 'gloomy', 'friday', '...', '1956967789', ',', 'enthusiasm', ',', 'czareaquino', ',', 'wants', 'to', 'hang', 'out', 'with', 'friends', 'SOON', '!', '1956968416', ',', 'neutral', ',', 'xkilljoyx', ',', "''", '@', 'dannycastillo', 'We', 'want', 'to', 'trade', 'with', 'someone', 'who', 'has', 'Houston', 'tickets', ',', 'but', 'no']

# %% [markdown]
# 4.4 Stem words

# %%
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()
stemmed = [porter.stem(word) for word in tokens]
print(stemmed[:100])
# Out:
# ['tweet_id', ',', 'sentiment', ',', 'author', ',', 'content', '1956967341', ',', 'empti', ',', 'xoshayz', ',', '@', 'tiffanylu', 'i', 'know', 'i', 'wa', 'listenin', 'to', 'bad', 'habit', 'earlier', 'and', 'i', 'start', 'freakin', 'at', 'hi', 'part', '=', '[', '1956967666', ',', 'sad', ',', 'wannamama', ',', 'layin', 'n', 'bed', 'with', 'a', 'headach', 'ughhhh', '...', 'waitin', 'on', 'your', 'call', '...', '1956967696', ',', 'sad', ',', 'coolfunki', ',', 'funer', 'ceremoni', '...', 'gloomi', 'friday', '...', '1956967789', ',', 'enthusiasm', ',', 'czareaquino', ',', 'want', 'to', 'hang', 'out', 'with', 'friend', 'soon', '!', '1956968416', ',', 'neutral', ',', 'xkilljoyx', ',', "''", '@', 'dannycastillo', 'We', 'want', 'to', 'trade', 'with', 'someon', 'who', 'ha', 'houston', 'ticket', ',', 'but', 'no']

# %% [markdown]
# #Converting into pdf

# %%
# !wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
from colab_pdf import colab_pdf
colab_pdf('Activity3_ACM_KashikaJain.ipynb')
# Out:
# --2021-06-10 17:29:44--  https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1864 (1.8K) [text/plain]
# Saving to: ‘colab_pdf.py’
#
# colab_pdf.py        100%[===================>]   1.82K  --.-KB/s    in 0s
#
# 2021-06-10 17:29:45 (21.7 MB/s) - ‘colab_pdf.py’ saved [1864/1864]
#
# Mounted at /content/drive/
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Extracting templates from packages: 100%
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/Activity3_ACM_KashikaJain.ipynb to pdf
# ...
